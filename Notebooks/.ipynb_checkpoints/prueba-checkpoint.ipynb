# %%
import os
import math
# Essential Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Preprocessing
from sklearn.preprocessing import MinMaxScaler
# Algorithms
from minisom import MiniSom
from tslearn.barycenters import dtw_barycenter_averaging
from tslearn.clustering import TimeSeriesKMeans
from sklearn.cluster import KMeans

from sklearn.decomposition import PCA
# Out:
# /home/ana/.local/lib/python3.8/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %%
directory = './formated'

mySeries = []
namesofMySeries = []
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        df = pd.read_csv(directory+"/"+filename)
        df = df.loc[:,["Y(hoy)"]]
        # While we are at it I just filtered the columns that we will be working on

        # ,set the date columns as index
        # and lastly, ordered the data according to our date index
        mySeries.append(df)
        df = pd.read_csv(directory+"/"+filename)

        df = df.loc[:,["Y(ayer)"]]
        mySeries.append(df)



        namesofMySeries.append(filename)
        namesofMySeries.append(filename)

# %%
print(len(mySeries))
print(namesofMySeries)
# Out:
# 60
# ['evolucion_diaria_intensidad.2021.08.17-00.01.01.csv', 'evolucion_diaria_intensidad.2021.08.17-00.01.01.csv', 'evolucion_diaria_intensidad.2022.03.17-00.01.01.csv', 'evolucion_diaria_intensidad.2022.03.17-00.01.01.csv', 'evolucion_diaria_intensidad.2022.05.30-00.01.01.csv', 'evolucion_diaria_intensidad.2022.05.30-00.01.01.csv', 'evolucion_diaria_intensidad.2022.05.01-00.01.01.csv', 'evolucion_diaria_intensidad.2022.05.01-00.01.01.csv', 'evolucion_diaria_intensidad.2019.04.17-23.59.01.csv', 'evolucion_diaria_intensidad.2019.04.17-23.59.01.csv', 'evolucion_diaria_intensidad.2018.11.18-00.01.01.csv', 'evolucion_diaria_intensidad.2018.11.18-00.01.01.csv', 'evolucion_diaria_intensidad.2021.06.02-23.59.01.csv', 'evolucion_diaria_intensidad.2021.06.02-23.59.01.csv', 'evolucion_diaria_intensidad.2019.03.22-00.01.01.csv', 'evolucion_diaria_intensidad.2019.03.22-00.01.01.csv', 'evolucion_diaria_intensidad.2020.11.17-00.01.01.csv', 'evolucion_diaria_intensidad.2020.11.17-00.01.01.csv', 'evolucion_diaria_intensidad.2021.05.01-00.01.01.csv', 'evolucion_diaria_intensidad.2021.05.01-00.01.01.csv', 'evolucion_diaria_intensidad.2022.09.07-23.59.01.csv', 'evolucion_diaria_intensidad.2022.09.07-23.59.01.csv', 'evolucion_diaria_intensidad.2020.04.20-23.59.01.csv', 'evolucion_diaria_intensidad.2020.04.20-23.59.01.csv', 'evolucion_diaria_intensidad.2021.04.16-00.01.01.csv', 'evolucion_diaria_intensidad.2021.04.16-00.01.01.csv', 'evolucion_diaria_intensidad.2021.02.23-00.01.01.csv', 'evolucion_diaria_intensidad.2021.02.23-00.01.01.csv', 'evolucion_diaria_intensidad.2020.03.09-23.59.01.csv', 'evolucion_diaria_intensidad.2020.03.09-23.59.01.csv', 'evolucion_diaria_intensidad.2021.09.06-23.59.01.csv', 'evolucion_diaria_intensidad.2021.09.06-23.59.01.csv', 'evolucion_diaria_intensidad.2021.02.19-00.01.01.csv', 'evolucion_diaria_intensidad.2021.02.19-00.01.01.csv', 'evolucion_diaria_intensidad.2020.11.11-23.59.01.csv', 'evolucion_diaria_intensidad.2020.11.11-23.59.01.csv', 'evolucion_diaria_intensidad.2021.06.27-23.59.01.csv', 'evolucion_diaria_intensidad.2021.06.27-23.59.01.csv', 'evolucion_diaria_intensidad.2019.11.23-23.59.01.csv', 'evolucion_diaria_intensidad.2019.11.23-23.59.01.csv', 'evolucion_diaria_intensidad.2019.11.06-23.59.01.csv', 'evolucion_diaria_intensidad.2019.11.06-23.59.01.csv', 'evolucion_diaria_intensidad.2020.10.01-00.01.01.csv', 'evolucion_diaria_intensidad.2020.10.01-00.01.01.csv', 'evolucion_diaria_intensidad.2019.08.13-23.59.01.csv', 'evolucion_diaria_intensidad.2019.08.13-23.59.01.csv', 'evolucion_diaria_intensidad.2021.03.07-23.59.01.csv', 'evolucion_diaria_intensidad.2021.03.07-23.59.01.csv', 'evolucion_diaria_intensidad.2020.04.27-00.01.01.csv', 'evolucion_diaria_intensidad.2020.04.27-00.01.01.csv', 'evolucion_diaria_intensidad.2021.11.10-23.59.01.csv', 'evolucion_diaria_intensidad.2021.11.10-23.59.01.csv', 'evolucion_diaria_intensidad.2022.03.04-23.59.01.csv', 'evolucion_diaria_intensidad.2022.03.04-23.59.01.csv', 'evolucion_diaria_intensidad.2019.01.30-23.59.01.csv', 'evolucion_diaria_intensidad.2019.01.30-23.59.01.csv', 'evolucion_diaria_intensidad.2020.01.31-00.01.01.csv', 'evolucion_diaria_intensidad.2020.01.31-00.01.01.csv', 'evolucion_diaria_intensidad.2022.05.09-23.59.01.csv', 'evolucion_diaria_intensidad.2022.05.09-23.59.01.csv']

# %%
fig, axs = plt.subplots(6,4,figsize=(25,25))
fig.suptitle('Series')
k=0
for i in range(6):
    for j in range(4):
        if i*4+j+1>len(mySeries): # pass the others that we can't fill
            continue


        axs[i, j].plot(mySeries[k].values)
        axs[i, j].set_title(namesofMySeries[k])


        k+=1
plt.show()

# %%
ind = 0
series_lengths=[]
for series in mySeries:
    print("["+str(ind)+"] "+str(series.index[0])+" "+str(series.index[len(series)-1]))
    ind+=1
    series_lengths.append(series.index[len(series)-1])
# Out:
# [0] 0 350
# [1] 0 350
# [2] 0 424
# [3] 0 424
# [4] 0 375
# [5] 0 375
# [6] 0 455
# [7] 0 455
# [8] 0 560
# [9] 0 560
# [10] 0 640
# [11] 0 640
# [12] 0 456
# [13] 0 456
# [14] 0 564
# [15] 0 564
# [16] 0 530
# [17] 0 530
# [18] 0 415
# [19] 0 415
# [20] 0 420
# [21] 0 420
# [22] 0 407
# [23] 0 407
# [24] 0 405
# [25] 0 405
# [26] 0 567
# [27] 0 567
# [28] 0 651
# [29] 0 651
# [30] 0 494
# [31] 0 494
# [32] 0 427
# [33] 0 427
# [34] 0 424
# [35] 0 424
# [36] 0 389
# [37] 0 389
# [38] 0 618
# [39] 0 618
# [40] 0 516
# [41] 0 516
# [42] 0 510
# [43] 0 510
# [44] 0 518
# [45] 0 518
# [46] 0 357
# [47] 0 357
# [48] 0 300
# [49] 0 300
# [50] 0 431
# [51] 0 431
# [52] 0 465
# [53] 0 465
# [54] 0 534
# [55] 0 534
# [56] 0 542
# [57] 0 542
# [58] 0 524
# [59] 0 524

# %%
max_len = max(series_lengths)
longest_series = None
for series in mySeries:
    if len(series)-1 == max_len:
        longest_series = series

# %%
print(longest_series)
# Out:
#        Y(ayer)
# 0    11.340705
# 1    10.943065
# 2    10.479152
# 3    10.147785
# 4    10.015239
# ..         ...
# 647        NaN
# 648        NaN
# 649        NaN
# 650        NaN
# 651        NaN
#
# [652 rows x 1 columns]

# %%
problems_index = []

for i in range(len(mySeries)):
    if len(mySeries[i])!= max_len:
        problems_index.append(i)
        mySeries[i] = mySeries[i].reindex(longest_series.index)

# %%
def nan_counter(list_of_series):
    nan_polluted_series_counter = 0
    for series in list_of_series:
        if series.isnull().sum().sum() > 0:
            nan_polluted_series_counter+=1
    print(nan_polluted_series_counter)

# %%
nan_counter(mySeries)
# Out:
# 59

# %%
for i in problems_index:
    mySeries[i].interpolate(limit_direction="both",inplace=True)

# %%
nan_counter(mySeries)
# Out:
# 1

# %%
print(mySeries[5])
# Out:
#        Y(ayer)
# 0    12.401079
# 1    12.334805
# 2    12.003439
# 3    11.539525
# 4    12.003439
# ..         ...
# 647  11.208159
# 648  11.208159
# 649  11.208159
# 650  11.208159
# 651  11.208159
#
# [652 rows x 1 columns]

# %%
for i in range(len(mySeries)):
    scaler = MinMaxScaler()
    mySeries[i] = MinMaxScaler().fit_transform(mySeries[i])
    mySeries[i]= mySeries[i].reshape(len(mySeries[i]))
# Out:
# /home/ana/.local/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:464: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /home/ana/.local/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:465: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
som_y =som_y2= math.ceil(math.sqrt(math.sqrt(len(mySeries))))
# I didn't see its significance but to make the map square,
# I calculated square root of map size which is
# the square root of the number of series
# for the row and column counts of som

som = MiniSom(som_y, som_y2,len(mySeries[0]), sigma=0.3, learning_rate = 0.1)

som.random_weights_init(mySeries)
som.train(mySeries, 50000)

# %%
# Little handy function to plot series
def plot_som_series_averaged_center(som_y2, som_y, win_map):
    fig, axs = plt.subplots(som_y2,som_y,figsize=(25,25))
    fig.suptitle('Clusters')
    for x in range(som_y):
        for y in range(som_y):
            cluster = (x,y)
            if cluster in win_map.keys():
                for series in win_map[cluster]:
                    axs[cluster].plot(series,c="gray",alpha=0.5)
                axs[cluster].plot(np.average(np.vstack(win_map[cluster]),axis=0),c="red")
            cluster_number = x*som_y+y+1
            axs[cluster].set_title(f"Cluster {cluster_number}")

    plt.show()

# %%
win_map = som.win_map(mySeries)
# Returns the mapping of the winner nodes and inputs

plot_som_series_averaged_center(som_y2, som_y, win_map)
